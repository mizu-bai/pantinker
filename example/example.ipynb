# %%
import pantinkerlog
import scienceplots
from matplotlib import pyplot as plt

# %%
df_npt_eq = pantinkerlog.tinker_log_to_df("npt_eq.log")
df_npt_eq
# Out:
#         Time  Total Energy     Potential   Kinetic En.  Temperature  \
# 0.1      0.1  52575.307200  28603.790898  23971.516720       202.34
# 0.2      0.2  51245.133267  27314.272057  23930.861210       202.00
# 0.3      0.3  54242.237486  29201.691193  25040.546293       211.37
# 0.4      0.4  56894.350821  30343.550817  26550.800004       224.12
# 0.5      0.5  59224.562677  31619.446554  27605.116122       233.02
# ...      ...           ...           ...           ...          ...
# 499.6  499.6  63258.672969  31347.547641  31911.125328       269.36
# 499.7  499.7  63284.128006  31502.757723  31781.370283       268.27
# 499.8  499.8  63310.598919  31524.087337  31786.511582       268.31
# 499.9  499.9  63341.745452  31500.155275  31841.590177       268.78
# 500.0  500.0  63342.752541  31384.965990  31957.786551       269.76
#
#           Pressure  Density
# 0.1     496.158128    395.5
# 0.2    1262.803342    401.2
# 0.3   -1142.115135    396.9
# 0.4     824.137020    399.4
# ...

# %%
# %matplotlib inline

with plt.style.context(["science", "no-latex"]):
    fig = plt.figure(dpi=150)
    ax = fig.add_subplot(111)
    ax.plot(df_npt_eq["Time"], df_npt_eq["Total Energy"])
    ax.set_xlabel("Time (ps)")
    ax.set_ylabel("Totol Energy (kJ/mol)")

# %%
# %matplotlib inline

with plt.style.context(["science", "no-latex"]):
    fig = plt.figure(dpi=150)
    ax = fig.add_subplot(111)
    ax.plot(df_npt_eq["Time"], df_npt_eq["Potential"])
    ax.set_xlabel("Time (ps)")
    ax.set_ylabel("Potential Energy (kJ/mol)")

# %%
# %matplotlib inline

with plt.style.context(["science", "no-latex"]):
    fig = plt.figure(dpi=150)
    ax = fig.add_subplot(111)
    ax.plot(df_npt_eq["Time"], df_npt_eq["Kinetic En."])
    ax.set_xlabel("Time (ps)")
    ax.set_ylabel("Kinetic Energy (kJ/mol)")

# %%
# %matplotlib inline

with plt.style.context(["science", "no-latex"]):
    fig = plt.figure(dpi=150)
    ax = fig.add_subplot(111)
    ax.plot(df_npt_eq["Time"], df_npt_eq["Temperature"])
    ax.set_xlabel("Time (ps)")
    ax.set_ylabel("Temperature (K)")

# %%
# %matplotlib inline

with plt.style.context(["science", "no-latex"]):
    fig = plt.figure(dpi=150)
    ax = fig.add_subplot(111)
    ax.plot(df_npt_eq["Time"], df_npt_eq["Pressure"])
    ax.set_xlabel("Time (ps)")
    ax.set_ylabel("Pressure (bar)")

# %%
# %matplotlib inline

with plt.style.context(["science", "no-latex"]):
    fig = plt.figure(dpi=150)
    ax = fig.add_subplot(111)
    ax.plot(df_npt_eq["Time"], df_npt_eq["Density"])
    ax.set_xlabel("Time (ps)")
    ax.set_ylabel("Density (kg/m^3)")
